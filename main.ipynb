# %% [markdown]
# This notebook is used to control the training of the model, as well as for other related tasks. First you need to mount Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# You can change the path so that it reach your gym_longicontrol file.

# %%
import os

folder_path = '/content/drive/Othercomputers/Moj MacBook Air'

# %%
path = os.path.join(folder_path, 'gym_longicontrol')
os.chdir(path)

# %% [markdown]
# Installing the gym_longicontrol python library. Python scripts from the folder are installed as packages.

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/Othercomputers/Moj%20MacBook%20Air/gym_longicontrol
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for gym_longicontrol
# ...

# %%
path = os.path.join(folder_path, 'gym_longicontrol/rl/pytorch')
os.chdir(path)

# %%
# !pip install pyglet==1.5.0  # Primjer verzije koja može sadržavati OrderedGroup

# %% [markdown]
# In order to get new .pkl file from car data, the following comented lines need to be run:

# %%
#cd '/content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs'

# %%
#!python create_power_estimator.py

# %%
#cd '/content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/rl/pytorch'

# %% [markdown]
# Now we can run main.py.

# %%
# !python main.py --num_epochs 30 --num_steps_per_epoch 10 --save_id 2
# Out:
# Izlaz streaminga skraćen je na ovoliko posljednjih redaka: 5000.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# We can visualize the results.

# %%
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.11).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
# Instalacija OpenGL i GLU
# !apt-get install -y libglu1-mesa libglu1-mesa-dev freeglut3-dev mesa-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libglu1-mesa is already the newest version (9.0.2-1).
# libglu1-mesa-dev is already the newest version (9.0.2-1).
# freeglut3-dev is already the newest version (2.8.1-6).
# mesa-utils is already the newest version (8.4.0-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
import OpenGL.GL as gl
import OpenGL.GLU as glu

# Provjera verzije OpenGL
print("OpenGL version:", gl.glGetString(gl.GL_VERSION))
print("GLU version:", glu.gluGetString(glu.GLU_VERSION))
# Out:
# OpenGL version: None
# GLU version: b'1.3'

# %%
# !python main.py --num_epochs 5 --num_steps_per_epoch 2 --load_id 2 -vis -rec
# Out:
# Izlaz streaminga skraćen je na ovoliko posljednjih redaka: 5000.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/core.py:49: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# circle:  1302
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MLPRegressor was fitted with feature names
#   warnings.warn(
# ...
