# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol'
# Out:
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol

# %% [markdown]
# Installing the gym_longicontrol python library.

# %%
pip install -e .
# Out:
# Obtaining file:///content/drive/Othercomputers/Moj%20MacBook%20Air/gym_longicontrol
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for gym_longicontrol
# ...

# %%
cd '/content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/rl/pytorch'
# Out:
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/rl/pytorch

# %%
# !pip install pyglet
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.6/936.6 kB 12.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# Kako bi se dobila nova .pkl datoteka treba pokrenuti sljedeće naredbe:

# %%
cd '/content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs'
# Out:
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs

# %%
# !python create_power_estimator.py
# Out:
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505021 Test Data.txt
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505025 Test Data.txt
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505039 Test Data.txt
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505044 Test Data.txt
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505029 Test Data.txt
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs/assets/vehicle/d3/BMW_electric_i3_2014/61505030 Test Data.txt
# ...

# %%
cd '/content/drive/Computers/Moj MacBook Air/gym_longicontrol/rl/pytorch'
# Out:
# [Errno 2] No such file or directory: '/content/drive/Computers/Moj MacBook Air/gym_longicontrol/rl/pytorch'
# /content/drive/Othercomputers/Moj MacBook Air/gym_longicontrol/gym_longicontrol/envs
