# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd '/content/drive/Computers/Moj MacBook Air/gym_longicontrol'

# %%
pip install -e .

# %%
cd '/content/drive/Computers/Moj MacBook Air/gym_longicontrol/rl/pytorch'
